# %%
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline
  
# load dataset of tips given in caffes
df = sns.load_dataset('tips')

# %%
## Here is the data of the tip given and info about the charge and the person recieving the service 
df.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
## Let's plot firstly the total bills:
sns.set_style()
sns.distplot(df['total_bill'], color ='black', bins = 25)
'''
Seeing the distribution of the total bills in the caffe we can see that most people - so is the average bill - is between 10 and 25 pounds 
and rarely to see people paying more than 40 pounds or less than 5, which seems almost never.
'''
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# '\nSeeing the distribution of the total bills in the caffe we can see that most people - so is the average tip - is between 10 and 25 pounds \nand rarely to see people paying more than 40 pounds or less than 5, which seems almost never.\n'

# %%
## Let's do plot for the tips given:

sns.set_style()
sns.distplot(df['tip'], color ='black', bins = 25)
'''
Seeing the distribution of the tips given in the caffe we can see that most people - so is the average tip - is between 2 and 4 pounds 
and rarely to see people paying more than 8 pounds or giving no tips at all, that also seems like never.
'''
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# '\nSeeing the distribution of the total bills in the caffe we can see that most people - so is the average tip - is between 10 and 25 pounds \nand rarely to see people paying more than 40 pounds or less than 5, which seems almost never.\n'

# %%
## Let's check the distribution of tips for males and females and try to create some insights:
df_male = df[df['sex']=='Male']
df_female = df[df['sex']=='Female']

sns.set_style()
sns.distplot(df_male['tip'], color ='gray', bins = 25) # bins can be 25, 30 or even 40 don't mind it..
sns.distplot(df_female['tip'], color ='red', bins = 25) # bins can be 25, 30 or even 40 don't mind it..
'''
Seeing the distribution of the 'Males' vs 'Females' tips given in the caffe we can see that most people - so is the average tip- 
knowing that red color represents females and gray color represents males, and we can notice that above average tips are more likely 
to be given by females than males in this caffe.
'''
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# '\nSeeing the distribution of the male tips given in the caffe we can see that most people - so is the average tip - is between 2 and 4 pounds \nand rarely to see people paying more than 8 pounds or giving no tips at all, that also seems like never.\n'

# %%
# Let's now compare between smokers and non smokers 

df_smoker = df[df['smoker']=='Yes']
df_nonsmok= df[df['smoker']=='No']

sns.set_style()
sns.distplot(df_smoker['tip'], color ='gray', bins = 25)
sns.distplot(df_nonsmok['tip'], color ='red', bins = 25) 
'''
Seeing the distribution of the 'Smokers' vs 'Non Smokers' tips given in the caffe we can see that most people - so is the average tip - 
knowing that red color represents Non Smokers and gray color represents Smokers, and we can notice that above average tips are more likely 
to be given by Non Smokers than Smokers in this caffe as their density of above average is more than the latter.
'''
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
## Let's try also to compare the time of the arrival of the recipient with their total bills and their tips respectively

df_dinner= df[df['time']=='Dinner']
df_lunch = df[df['time']=='Lunch']

sns.set_style()
sns.distplot(df_dinner['total_bill'], color ='blue', bins = 25)
sns.distplot(df_lunch['total_bill'], color ='red', bins = 25) 
'''
Seeing this distribution we can deduce that the above average totall bills are more likely to be in dinner time which is indicated in blue,
however the less than average totall bills are more likely to be in lunch time which is indicated in red here
'''
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# '\nSeeing this distribution we can deduce that the \n'

# %%
## Let's try also to compare the time of the arrival of the recipient with their total bills and their tips respectively

df_dinner= df[df['time']=='Dinner']
df_lunch = df[df['time']=='Lunch']

sns.set_style()
sns.distplot(df_dinner['tip'], color ='blue', bins = 25)
sns.distplot(df_lunch['tip'], color ='red', bins = 25) 
'''
Seeing this distribution we can not deduce any strong preferences above or under average in tips in different day times. 
'''
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# '\nSeeing this distribution we can deduce that the above average totall bills are more likely to be in dinner time which is indicated in blue,\nhowever the less than average totall bills are more likely to be in lunch time which is indicated in red here\n'

# %%
## Let's now try to plot the total bills vs the tip in the regression plot

sns.set_style('whitegrid')
sns.lmplot(x ='total_bill', y ='tip', data = df)
'''
Here it's easy to notice how the two variables are correlated and a high bill will mostly mean a good tip 
'''

# %%
## Let's not forget to visualize males and females seperately
sns.set_style('whitegrid')
sns.lmplot(x ='total_bill', y ='tip', data = df, 
           hue ='sex', markers =['o', 'v'])
''' 
We can add to our insights from this reg-plot that in high total bills - more than 40, males are more likely to give higher tips 
more than females.
'''

# %%
## Let's not forget to visualize smokers and non-smokers seperately
sns.set_style('whitegrid')
sns.lmplot(x ='total_bill', y ='tip', data = df,
           hue ='time', markers =['o', 'v'])
''' 
That assures that in most cases lunch time visitors give more tips than dinner timers.
'''
# Out:
# ' \nThat assures that in most cases lunch time visitors give more tips than dinner timers.\n'

# %%
## Combining both things
sns.lmplot(x ='total_bill', y ='tip', data = df, col ='sex', 
           row ='time', hue ='smoker', aspect = 0.6, 
           size = 4, palette ='coolwarm')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
## Let's not forget to visualize smokers and non-smokers seperately
sns.set_style('whitegrid')
sns.lmplot(x ='total_bill', y ='tip', data = df,
           hue ='smoker', markers =['o', 'v'])
''' 
That assures that in most cases non-smokers give more tips than smokers.
'''
# Out:
# ' \nThat assures that in most cases non-smokers give more tips than smokers.\n'

# %%
## Multi plotting for different sizes
sns.pairplot(df, hue ='size') 
plt.show()

# %%
s
